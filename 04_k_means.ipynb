# %%
# importion
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
# 自制二位数据
X = [[1,2], [3,7], [74,5], [1,0], [5,7], [8,9]]

# %%
# 建模
kmeans = KMeans(n_clusters = 2)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=2)

# %%
print(kmeans.labels_)
# Out:
# [0 0 1 0 0 0]

# %%
print(kmeans.cluster_centers_)
# Out:
# [[ 3.6  5. ]
#  [74.   5. ]]

# %%
for i in range(len(X)) :
  plt.scatter(X[i][0], X[i][1], c= 'r' if kmeans.labels_[i] else 'b')
for center in kmeans.cluster_centers_ :
  plt.scatter(center[0], center[1], c = 'k', marker = 'x')
plt.title("KMeans Clustering Demo")
plt.show()

# %%
import matplotlib.pyplot as plt

x = [0, 1, 2, 3, 4, 5]
y = [0, 1, 4, 9, 16, 25]

plt.plot(x, y)                  # 把点连成线
plt.xlabel("Input x")           # 给x轴贴名字
plt.ylabel("Output y = x^2")    # 给y轴贴名字
plt.title("Quadratic Function") # 给整个图一个标题
plt.show()                      # 显示图像
